# %%
import pandas as pd

# %%
df = pd.read_csv('data/surveyres2023.csv' , index_col='ResponseId')
df_schema = pd.read_csv('data/surveyschema2023.csv')

# %%
pd.set_option('display.max_columns' , 84)
pd.set_option('display.max_rows' , 84)

# %%
df.head(10)
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 1           I agree                                      None of these
# 2           I agree                     I am a developer by profession
# 3           I agree                     I am a developer by profession
# 4           I agree                     I am a developer by profession
# 5           I agree                     I am a developer by profession
# 6           I agree                     I am a developer by profession
# 7           I agree                     I am a developer by profession
# 8           I agree                     I am a developer by profession
# 9           I agree  I am not primarily a developer, but I write co...
# 10          I agree                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 1           18-24 years old
# 2           25-34 years old
# 3           45-54 years old
# 4           25-34 years old
# ...

# %%
df_schema
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
pd.set_option('display.max_colwidth', None)
df_schema.loc[[15,16],'question']
# Out:
# 15                             Including any education, how many years have you been coding in total?
# 16    NOT including education, how many years have you coded professionally (as a part of your work)?
# Name: question, dtype: object

# %%
df_schema = pd.read_csv('data/surveyschema2023.csv' , index_col = 'qname' )
df_schema
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
#df_schema = df_schema.drop(['S0','Q120','S1','S2','S3','S4','S5','S6','S7'], axis=0, inplace=True)
#where 1 is the axis number (0 for rows and 1 for columns.)
#IMMMMMMMPORTNATTTTT!!!! : As we set index_col = 'qname' qname isn't in our columns anymore cuz it is now our indexer so for deleting and dropping columns we should use our axis=0 therefore we can now delete them as our rows.
#WE also can use:
#df = df.drop(columns=['column_nameA', 'column_nameB'])
#I don't know why  but it doesn't worked!?

# %%
df_schema.drop(["S0","S1","S2","S3","S4","S5","S6","S7","Q120","Q310"] , inplace = True)

# %%
df_schema = df_schema.drop(columns=['type', 'selector' , 'qid' , 'force_resp'])

# %%
df_schema
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     question
# qname
# ...

# %%
df.loc[89184]
# Out:
# Q120                                                                                                                                                                                                                    I agree
# MainBranch                                                                                                                                                                                       I am a developer by profession
# Age                                                                                                                                                                                                             35-44 years old
# Employment                                                                                                                                                                                                  Employed, full-time
# ...

# %%
df['Country'] = df['Country'].apply(lambda x:'USA' if x=='United States of America' else 'Iran' if x=='Iran, Islamic Republic of...' else x )
df['Country']
# Out:
# ResponseId
# 1                NaN
# 2                USA
# 3                USA
# 4                USA
# 5        Philippines
#             ...
# 89180         Brazil
# 89181        Romania
# 89182         Israel
# 89183    Switzerland
# 89184           Iran
# Name: Country, Length: 89184, dtype: object

# %%
filt = ((df['CompTotal']>96000) & (df['Country']=='USA') & (df['LanguageHaveWorkedWith'].str.contains('Python' , na=False)))
df.loc[filt,['CompTotal','LanguageHaveWorkedWith','Country']]
# Out:
#             CompTotal  \
# ResponseId
# 2            285000.0
# 14           150000.0
# 111          145000.0
# 122          200990.0
# 138          150000.0
# ...               ...
# 89079        150000.0
# 89087        182333.0
# 89113        187000.0
# 89114        200000.0
# 89140        215000.0
#
#                                                                                           LanguageHaveWorkedWith  \
# ResponseId
# 2                                                                                     HTML/CSS;JavaScript;Python
# 14                                                                                             C;C++;Python;Rust
# 111                                                                        HTML/CSS;JavaScript;Python;TypeScript
# 122                                                                Go;HTML/CSS;JavaScript;PowerShell;Python;Rust
# ...

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                                           Employment  \
# ...

# %%
#How to reorder columns:
#df['column1'],df['column2'] = df['column2'],df['column1']

# %%
df_schema
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     question
# qname
# ...

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                                           Employment  \
# ...

# %%
def deleting_cols():
    cols = input('what are your string names that u want to erase from your df columns? ').split(' ')
    for i in cols:              
        for col in df.columns:
            if i in col:
                df.drop(col, axis=1 , inplace = True)

# %%
deleting_cols()
# Out:
# what are your strings that u want to erase from your df cols?  Knowledge_ Frequency_

# %%
del df['Q120']

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1                            None of these     18-24 years old
# 2           I am a developer by profession     25-34 years old
# 3           I am a developer by profession     45-54 years old
# 4           I am a developer by profession     25-34 years old
# 5           I am a developer by profession     25-34 years old
# ...                                    ...                 ...
# 89180       I am a developer by profession     25-34 years old
# 89181       I am a developer by profession     18-24 years old
# 89182          I code primarily as a hobby   Prefer not to say
# 89183       I am a developer by profession  Under 18 years old
# 89184       I am a developer by profession     35-44 years old
#
#                                                                           Employment  \
# ResponseId
# 1                                                                                NaN
# ...
